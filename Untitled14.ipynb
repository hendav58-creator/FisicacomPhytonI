# %% [markdown]
# <a href="https://colab.research.google.com/github/hendav58-creator/FisicacomPhytonI/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Familia = {'Henrique':48, 'Marcelo':65, 'Rosangela':51}
Familia
# Out:
# {'Henrique': 48, 'Marcelo': 65, 'Rosangela': 51}

# %%
Familia['Marcelo']
# Out:
# 65

# %%
Familia['Rosangela']
# Out:
# 51

# %%
Familia['Henrique'] = 68
Familia
#Corrigida
# Out:
# {'Henrique': 68, 'Marcelo': 65, 'Rosangela': 51}

# %%
Familia[38] = 'Natalia'
Familia[34] = 'Marcela'
Familia
# Out:
# {'Henrique': 68,
#  'Marcelo': 65,
#  'Rosangela': 51,
#  37: 'Natalia',
#  34: 'Marcela',
#  38: 'Natalia'}
